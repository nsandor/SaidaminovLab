# %%
import pySMUuvic as psu

# # To check Keithley Address
# psu.get_Keithley_address()

save_dir = '/Users/lznus/Desktop/Data-Keithley/'
address = 'USB0::0x05E6::0x2450::04491080::INSTR'
operation_mode = '04_tI-pulse'

project_dir = psu.project_start(save_dir, operation_mode)
# Out:
# 01: Integration-Project
# 02: Parinaz
# 03: Paul
# 04: Ren
# 05: Sergey
# 06: Soumya
# 07: Yuki
# Select your user ID 4
# Create a new folder (0) or Use an existing folder (1)
#  0
# Enter project name:
#  2nd-try_washed
# Folder named "/Users/lznus/Desktop/Data-Keithley//Ren/04_tI-pulse" has been prepared.
# Folder named "/Users/lznus/Desktop/Data-Keithley//Ren/04_tI-pulse/240125_2nd-try_washed" has been prepared.
# Folder named "/Users/lznus/Desktop/Data-Keithley//Ren/04_tI-pulse/240125_2nd-try_washed/figures" has been prepared.

# %%
# Decide running parameters and then run it
psu.run_tI_pulse(
    project_dir = project_dir,
    source_voltage = 1, # V
    delay_time = 30, # sec, minimum is 0.5
    t_ON = 0.02, #ms
    duration = 300, # sec, total time
    ILIMIT = 0.01, # A
    terminals = 'REAR', # 'FRONT' or 'REAR' panel
    address = address
)
# Out:
# Enter the file name [XXX], it will be "/Users/lznus/Desktop/Data-Keithley//Ren/04_tI-pulse/240125_2nd-try_washed/XXX.csv"
#   [XXX] =  S1231213_1V-pulse_33.6uGys
# Program completed

# %%
times
