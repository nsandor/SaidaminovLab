# %%
import pySMUuvic as psu

# # To check Keithley Address
# psu.get_Keithley_address()

save_dir = '/Users/lznus/Desktop/Data-Keithley/'
address = 'USB0::0x05E6::0x2450::04491080::INSTR'
operation_mode = '02_IV'

project_dir = psu.project_start(save_dir, operation_mode)
# Out:
# 01: Parinaz
# 02: Paul
# 03: Ren
# 04: Sergey
# 05: Soumya
# 06: Yuki
# Select your user ID 1
# Create a new folder (0) or Use an existing folder (1)
#  0
# Enter project name:
#  231030-MAPI-delaminated-crystals
# Folder named "/Users/lznus/Desktop/Data-Keithley//Parinaz/02_IV/231109_231030-MAPI-delaminated-crystals" has been prepared.
# Folder named "/Users/lznus/Desktop/Data-Keithley//Parinaz/02_IV/231109_231030-MAPI-delaminated-crystals/figures" has been prepared.

# %%
#### Run the measurement
psu.run_IV(
    project_dir = project_dir,
    v_range = [0, 10] #V
    step_size = 0.5, #V/step
    scan_rate = 10, #V/s
    ILIMIT = 0.05, # A
    direction = 'B', # B:both (F -> R), F:forward, R:reverse
    terminals = 'FRONT', # 'FRONT' or 'REAR' panel
    address = address
)
# Out:
# Enter file name:  2
# Program completed

# %%
# Grab and show the data list
data_list = psu.data_list(project_dir)
# Out:
# 00: 01_40kV-35mA-33.6uGys-F
# 01: 01_40kV-35mA-33.6uGys-R
# 02: 01_40kV-35mA-70mGys-F
# 03: 01_40kV-35mA-70mGys-R
# 04: 01_dark-F
# 05: 01_dark-R
# 06: 02_40kV-35mA-70mGys-F
# 07: 02_40kV-35mA-70mGys-R
# 08: 02_dark-F
# 09: 02_dark-R

# %%
plot_index = [7,9] # Chose the numbers

psu.IV_plot(data_list, plot_index, project_dir, xlog = False, ylog = False)
