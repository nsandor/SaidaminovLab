# %% [markdown]
# ## 1st: create a folder

# %%
import pySMUuvic as psu

# # To check Keithley Address
# psu.get_Keithley_address()

save_dir = '/Users/lznus/Desktop/Data-Keithley'
address = 'USB0::0x05E6::0x2450::04491080::INSTR'
operation_mode = '01_tI'

project_dir = psu.project_start(save_dir, operation_mode)
# Out:
# 01: Parinaz
# 02: Paul
# 03: Ren
# 04: Sergey
# 05: Soumya
# 06: Yuki
# Select your user ID 4
# Create a new folder (0) or Use an existing folder (1)
#  0
# Enter project name:
#  CsPbBr3
# Folder named "/Users/lznus/Desktop/Data-Keithley/Sergey/01_tI/231109_CsPbBr3" has been prepared.
# Folder named "/Users/lznus/Desktop/Data-Keithley/Sergey/01_tI/231109_CsPbBr3/figures" has been prepared.

# %% [markdown]
# ## 2nd: set parameters and run

# %%
# Decide running parameters and then run it
psu.run_tI(
    project_dir = project_dir,
    source_voltage = 10, # V
    delay_time = 0.5, # sec, minimum is 0.5
    duration = 290, # sec, total time
    ILIMIT = 0.01, # A
    terminals = 'FRONT', # 'FRONT' or 'REAR' panel
    address = address
)
'''
75 - 35
117 - 28
157 - 21
197 - 14
237 - 7
'''

'''
77 - .40
137 - .32
197 - .24
257 - .16
317 - .08
'''
# Out:
# Enter the file name [XXX], it will be "/Users/lznus/Desktop/Data-Keithley/Sergey/01_tI/231109_CsPbBr3/XXX.csv"
#  231107-S3-E60_Ag-CPB-Au_010V_33.6-20.2uGys_h-move
# Program completed
# '\n77 - .40\n137 - .32\n197 - .24\n257 - .16\n317 - .08\n'

# %% [markdown]
# ## Make a combined figure

# %%
# Grab and show the data list
data_list = psu.data_list(project_dir)
# Out:
# 00: 231026-S1-E60_Au-CPB-Au
# 01: 231107-S2-E60_InGa-CPB-Au_002V_33.6-6.7uGys_e-move

# %%
plot_index = [0,1] # Chose the numbers

psu.tI_plot(data_list, plot_index, project_dir)
# Out:
# filename a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 3>()
#       1 plot_index = [0,1] # Chose the numbers
# ----> 3 psu.tI_plot(data_list, plot_index, save = True)
#
# File ~\Desktop\Keithley2450\pySMUuvic.py:865, in tI_plot(data_list, plot_index, save)
#     863 if save:
#     864     fig_name = input('filename')
# --> 865     fig_com_dir = f"{fig_dir}/combined"
#     866     make_folder(fig_com_dir)
#     867     fig_com_path = os.path.join(fig_com_dir, fig_name + '.png')
#
# NameError: name 'fig_dir' is not defined
