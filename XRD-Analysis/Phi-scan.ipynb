# %%
### MAPbBr3 201 Phi scan
import matplotlib.pyplot as plt
import pandas as pd

path = '/Users/yukiharuta/Desktop/Temp-Data/MAPbBr3-Paper/02_XRD/5_Others/230920_A_0.2_201Phi-scan.csv'
df = pd.read_csv(path, skiprows=31)
df

x = df['Angle'].to_list()
y = df[' Intensity'].to_list()

offset = 40
x = [(n-offset)%360 for n in x]

plt.plot(x,y)
